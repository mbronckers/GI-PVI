# %%
import pstats

p = pstats.Stats('profile.stats')
p.sort_stats('time').print_stats()
# Out:
# Mon Aug 15 14:51:26 2022    profile.stats
#
#          138624045 function calls (137325642 primitive calls) in 34.420 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1000    6.231    0.006    6.231    0.006 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     55890    5.563    0.000   12.549    0.000 /opt/homebrew/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py:727(getmodule)
# 25738403/25737344    3.018    0.000    3.037    0.000 {built-in method builtins.hasattr}
#  25543758    2.001    0.000    2.586    0.000 /opt/homebrew/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py:64(ismodule)
#        44    1.821    0.041    1.821    0.041 {method 'encode' of 'ImagingEncoder' objects}
#     21066    1.208    0.000    1.208    0.000 {built-in method matmul}
# ...
